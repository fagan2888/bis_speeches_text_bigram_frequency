# %%
from utils import * 
from config import parameters

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from math import sqrt
from statsmodels.tsa.stattools import grangercausalitytests

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fred_gdp_quarterly_csv_filepath = parameters.fred_gdp_quarterly_csv_filepath 
fred_unemp_quarterly_csv_filepath = parameters.fred_unemp_quarterly_csv_filepath 
fred_unemp_not_adjusted_quarterly_csv_filepath = os.path.join(parameters.data_dir, 'fred_unemp_not_adjusted_quarterly.csv') 
fred_interest_rate_quarterly_csv_filepath = os.path.join(parameters.data_dir, 'fred_interest_rate_quarterly.csv') 
fred_ted_spread_quarterly_csv_filepath = os.path.join(parameters.data_dir, 'fred_ted_spread_quarterly.csv') 
yahoo_djia_quarterly_csv_filepath = os.path.join(parameters.data_dir, 'yahoo_djia_quarterly.csv')
fred_index_filepath_dict = {'gdp': fred_gdp_quarterly_csv_filepath, 'unemployment': fred_unemp_quarterly_csv_filepath, 'unemployment_not_adjusted': fred_unemp_not_adjusted_quarterly_csv_filepath, 'interest_rate': fred_interest_rate_quarterly_csv_filepath, 'ted_spread': fred_ted_spread_quarterly_csv_filepath, 'djia': yahoo_djia_quarterly_csv_filepath}
fred_index_dict_pkl_filepath = os.path.join(parameters.output_base_dir, 'fred_index_dict.pkl')
fred_index_dict = get_index_dict(fred_index_dict_pkl_filepath, fred_index_filepath_dict)

bigram_uniqueness_strength_pkl_filepath = os.path.join(parameters.output_base_dir, 'bigram-emerging_topic_score-strength_20191123-19-10-46.pkl')
bigram_uniqueness_strength_dict = load_pkl(bigram_uniqueness_strength_pkl_filepath)
# Out:
# base_dir: /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency
# Parameters(
#   sentence_length_outlier = [0, 1, 2, 181, 252]
#   bigram_window_size = 15
#   bigram_max_rank = None
#   stopword_list = ['financial', 'market', 'federal', 'bank', 'banking', 'bankers', 'speech', 'bi', 'review', 'year', 'reserve', 'policy', 'state', 'central', 'board', 'percent', 'rate', 'mr', 'alan', 'greenspan', 'ben', 'bernanke', 'janet', 'yellen', 'jerome', 'powell', 'vol', 'ha', 'wa', 'ii']
#   ws_quarterly = 4
#   ws_semiannually = 2
#   ws_annually = 1
#   strength_alpha = 0.9
#   base_dir = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency
#   data_dir = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/data
#   output_base_dir = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/output
#   bis_raw_pkl_filepath = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/data/bis_w_content_FINAL.pkl
#   fred_gdp_quarterly_csv_filepath = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/data/fred_gdp_quarterly.csv
#   fred_gdp_semiannually_csv_filepath = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/data/fred_gdp_semiannually.csv
#   fred_gdp_annually_csv_filepath = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/data/fred_gdp_annually.csv
#   fred_unemp_quarterly_csv_filepath = /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/data/fred_unemp_quarterly.csv
# )
# Completed loading: /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/output/fred_index_dict.pkl
# Completed loading: /home/dmlab/jihye/GIT/bis_speeches_text_bigram_frequency/output/bigram-emerging_topic_score-strength_20191123-19-10-46.pkl

# %%
def rescale_rolling(values, rolling_window):
    df = pd.DataFrame(values)
    normalized = (df - df.rolling(rolling_window).mean()) / df.rolling(rolling_window).std()
    return normalized

def show_plt_chart_rolling(x_, y_, x_ticks_list, rolling_window, x_label, y_label, max_lag=5, with_legend=True, show=True):
    x = np.array(x_)
    y = np.array(y_)

    x_normalized = rescale_rolling(x, rolling_window)[rolling_window-1:].fillna(0).reset_index(drop=True)
    y_normalized = rescale_rolling(y, rolling_window)[rolling_window-1:].fillna(0).reset_index(drop=True)
    x_ticks_list = pd.Series(x_ticks_list)[rolling_window-1:].fillna(0).reset_index(drop=True)
    
    if show:
        plt.plot(x_normalized, 'g', label=x_label)
        plt.plot(y_normalized,'r', label=y_label)
        plt.xticks(list(range(len(x_ticks_list))), x_ticks_list, rotation='vertical')    
        plt.grid()
        if with_legend:
            plt.legend()
    
    x_normalized_df = x_normalized
    y_normalized_df = y_normalized
    df = pd.concat([y_normalized_df, x_normalized_df], axis=1)   # the predictor (X) is in the second column.
    return grangercausalitytests(df, maxlag=max_lag)

plt.rcParams["figure.figsize"] = (20,5)

# %% [markdown]
# ### frequency, emerging_topic_score, strength

# %%
# parameter
top_n = 50
rolling_window = 3

# %%
indices = ['gdp', 'unemployment', 'unemployment_not_adjusted', 'interest_rate', 'ted_spread', 'djia']
period_dict = dict()
proposed_data_x_dict = {'frequency': dict(), 'emerging_topic_score': dict(), 'strength': dict()}
fred_data_y_dict = dict()
for index_ in indices:
    period_dict[index_] = list()
    proposed_data_x_dict['frequency'][index_] = list()
    proposed_data_x_dict['emerging_topic_score'][index_] = list()
    proposed_data_x_dict['strength'][index_] = list()
    fred_data_y_dict[index_] = list()

# align
for index_name in fred_data_y_dict.keys():
    _period_dict = bigram_uniqueness_strength_dict['quarterly']
    data_of_previous_period = False
    for _period in sorted(_period_dict.keys()): 
        
        # TO TEST ROBUSTNESS
#         if _period[:4] not in ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010']:
#             continue
            
        # in case of fred_index_dict has no recent or past information.
        if _period not in fred_index_dict[index_name]:
            continue
        count = 0
        _sum_freq, _sum_emerging_topic_score, _sum_strength = 0, 0, 0
        for _bigram, (_freq, _emerging_topic_score, _strength) in sorted(_period_dict[_period].items(),
                                                               key=lambda t: t[-1][0],
                                                               reverse=True):  # CONTROL PRINTING ORDER
            count += 1
            _sum_freq += _freq
            _sum_emerging_topic_score += _emerging_topic_score
            _sum_strength += _strength
            
            if count == top_n:
                if not data_of_previous_period:
                    data_of_previous_period_freq = -_sum_freq
                    data_of_previous_period_emerging_topic_score = -_sum_emerging_topic_score
                    data_of_previous_period_strength = -_sum_strength
                    data_of_previous_period = True
                    continue
                    
                # data append
                period_dict[index_name].append(_period)
                proposed_data_x_dict['frequency'][index_name].append(data_of_previous_period_freq)
                proposed_data_x_dict['emerging_topic_score'][index_name].append(data_of_previous_period_emerging_topic_score)
                proposed_data_x_dict['strength'][index_name].append(data_of_previous_period_strength)
                fred_data_y_dict[index_name].append(float(fred_index_dict[index_name][_period]))
                
                data_of_previous_period_freq = -_sum_freq
                data_of_previous_period_emerging_topic_score = -_sum_emerging_topic_score
                data_of_previous_period_strength = -_sum_strength
                
                break

# %%
test_periods_dict = dict()
amount = 28
end_ = int(84 / amount)
for i in range(1, end_+1):
    test_periods_dict[i] = (amount*(i-1) , amount*i)  
test_periods_dict
# Out:
# {1: (0, 28), 2: (28, 56), 3: (56, 84)}

# %%
for s_, e_ in test_periods_dict.values():
    print(period_dict['unemployment_not_adjusted'][s_:e_])
# Out:
# ['1998_Q3', '1998_Q4', '1999_Q1', '1999_Q2', '1999_Q3', '1999_Q4', '2000_Q1', '2000_Q2', '2000_Q3', '2000_Q4', '2001_Q1', '2001_Q2', '2001_Q3', '2001_Q4', '2002_Q1', '2002_Q2', '2002_Q3', '2002_Q4', '2003_Q1', '2003_Q2', '2003_Q3', '2003_Q4', '2004_Q1', '2004_Q2', '2004_Q3', '2004_Q4', '2005_Q1', '2005_Q2']
# ['2005_Q3', '2005_Q4', '2006_Q1', '2006_Q2', '2006_Q3', '2006_Q4', '2007_Q1', '2007_Q2', '2007_Q3', '2007_Q4', '2008_Q1', '2008_Q2', '2008_Q3', '2008_Q4', '2009_Q1', '2009_Q2', '2009_Q3', '2009_Q4', '2010_Q1', '2010_Q2', '2010_Q3', '2010_Q4', '2011_Q1', '2011_Q2', '2011_Q3', '2011_Q4', '2012_Q1', '2012_Q2']
# ['2012_Q3', '2012_Q4', '2013_Q1', '2013_Q2', '2013_Q3', '2013_Q4', '2014_Q1', '2014_Q2', '2014_Q3', '2014_Q4', '2015_Q1', '2015_Q2', '2015_Q3', '2015_Q4', '2016_Q1', '2016_Q2', '2016_Q3', '2016_Q4', '2017_Q1', '2017_Q2', '2017_Q3', '2017_Q4', '2018_Q1', '2018_Q2', '2018_Q3', '2018_Q4', '2019_Q1', '2019_Q2']

# %% [markdown]
# ### Let's check..

# %%
max_lag = 5

to_check_list = list()

indices = ['djia', 'unemployment_not_adjusted', 'unemployment', 'gdp', 'interest_rate', 'ted_spread']
for index_name in indices:
    for i in ['frequency', 'strength', 'emerging_topic_score']:
        for test_key, (s_, e_) in test_periods_dict.items():
            x_ = proposed_data_x_dict[i][index_name][s_:e_]
            y_ = fred_data_y_dict[index_name][s_:e_]
            x_ticks_list = period_dict[index_name][s_:e_]
            x_label = 'standardized: -(sum of top5 ' + i +' )'
            y_label = 'standardized: Real '+ index_name +' (Percent Change)'
            df = show_plt_chart_rolling(x_, y_, x_ticks_list, rolling_window, x_label, y_label, max_lag=max_lag, with_legend=False, show=False)

            print('\n\n','='*10)
            title = index_name + ',   ' + str(i) + ',   test_period=' + str(test_key)
            print(title)
            print('='*10)
            print('n_lag \t p-value')
            for n_lag in range(1, max_lag+1):
                p_value_str = '%.4f' % df[n_lag][0]['params_ftest'][1]
                if float(p_value_str) < 0.1:
                    p_value_str += '★'
                    to_check_list.append(title)
                elif float(p_value_str) < 0.05:
                    p_value_str += '★★'
                    to_check_list.append(title)
                print('%d \t %s'% (n_lag, p_value_str))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7271  , p=0.4030  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.8262  , p=0.3634  , df=1
# likelihood ratio test: chi2=0.8128  , p=0.3673  , df=1
# parameter F test:         F=0.7271  , p=0.4030  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1247  , p=0.3454  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=2.8413  , p=0.2416  , df=2
# likelihood ratio test: chi2=2.6853  , p=0.2611  , df=2
# parameter F test:         F=1.1247  , p=0.3454  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4969  , p=0.2534  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=6.4553  , p=0.0914  , df=3
# likelihood ratio test: chi2=5.6898  , p=0.1277  , df=3
# parameter F test:         F=1.4969  , p=0.2534  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1180  , p=0.3899  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=7.5678  , p=0.1088  , df=4
# likelihood ratio test: chi2=6.5041  , p=0.1645  , df=4
# parameter F test:         F=1.1180  , p=0.3899  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5507  , p=0.7352  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=5.7821  , p=0.3280  , df=5
# likelihood ratio test: chi2=5.1074  , p=0.4029  , df=5
# parameter F test:         F=0.5507  , p=0.7352  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   frequency,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.4030
# 2 	 0.3454
# 3 	 0.2534
# 4 	 0.3899
# 5 	 0.7352
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3155  , p=0.5800  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.3585  , p=0.5493  , df=1
# likelihood ratio test: chi2=0.3560  , p=0.5508  , df=1
# parameter F test:         F=0.3155  , p=0.5800  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1620  , p=0.8516  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.4094  , p=0.8149  , df=2
# likelihood ratio test: chi2=0.4059  , p=0.8163  , df=2
# parameter F test:         F=0.1620  , p=0.8516  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7720  , p=0.5264  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=3.3292  , p=0.3436  , df=3
# likelihood ratio test: chi2=3.1092  , p=0.3751  , df=3
# parameter F test:         F=0.7720  , p=0.5264  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7900  , p=0.5521  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=5.3477  , p=0.2534  , df=4
# likelihood ratio test: chi2=4.7870  , p=0.3099  , df=4
# parameter F test:         F=0.7900  , p=0.5521  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7441  , p=0.6082  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=7.8130  , p=0.1668  , df=5
# likelihood ratio test: chi2=6.6424  , p=0.2486  , df=5
# parameter F test:         F=0.7441  , p=0.6082  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   frequency,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.5800
# 2 	 0.8516
# 3 	 0.5264
# 4 	 0.5521
# 5 	 0.6082
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8944  , p=0.3546  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.0164  , p=0.3134  , df=1
# likelihood ratio test: chi2=0.9963  , p=0.3182  , df=1
# parameter F test:         F=0.8944  , p=0.3546  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7145  , p=0.2068  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=4.3313  , p=0.1147  , df=2
# likelihood ratio test: chi2=3.9819  , p=0.1366  , df=2
# parameter F test:         F=1.7145  , p=0.2068  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4291  , p=0.2711  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=6.1631  , p=0.1039  , df=3
# likelihood ratio test: chi2=5.4605  , p=0.1410  , df=3
# parameter F test:         F=1.4291  , p=0.2711  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.7826  , p=0.0067  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=39.1436 , p=0.0000  , df=4
# likelihood ratio test: chi2=22.4880 , p=0.0002  , df=4
# parameter F test:         F=5.7826  , p=0.0067  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=5.8950  , p=0.0086  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=61.8978 , p=0.0000  , df=5
# likelihood ratio test: chi2=28.8348 , p=0.0000  , df=5
# parameter F test:         F=5.8950  , p=0.0086  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   frequency,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.3546
# 2 	 0.2068
# 3 	 0.2711
# 4 	 0.0067★
# 5 	 0.0086★
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0435  , p=0.8367  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0494  , p=0.8241  , df=1
# likelihood ratio test: chi2=0.0494  , p=0.8241  , df=1
# parameter F test:         F=0.0435  , p=0.8367  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4428  , p=0.6487  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.1188  , p=0.5716  , df=2
# likelihood ratio test: chi2=1.0935  , p=0.5788  , df=2
# parameter F test:         F=0.4428  , p=0.6487  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2899  , p=0.3119  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=5.5626  , p=0.1349  , df=3
# likelihood ratio test: chi2=4.9819  , p=0.1731  , df=3
# parameter F test:         F=1.2899  , p=0.3119  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8542  , p=0.5163  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=5.7820  , p=0.2160  , df=4
# likelihood ratio test: chi2=5.1336  , p=0.2739  , df=4
# parameter F test:         F=0.8542  , p=0.5163  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4544  , p=0.8013  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=4.7716  , p=0.4444  , df=5
# likelihood ratio test: chi2=4.2997  , p=0.5071  , df=5
# parameter F test:         F=0.4544  , p=0.8013  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   strength,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.8367
# 2 	 0.6487
# 3 	 0.3119
# 4 	 0.5163
# 5 	 0.8013
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1808  , p=0.6748  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.2054  , p=0.6504  , df=1
# likelihood ratio test: chi2=0.2046  , p=0.6510  , df=1
# parameter F test:         F=0.1808  , p=0.6748  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5055  , p=0.6111  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.2770  , p=0.5281  , df=2
# likelihood ratio test: chi2=1.2442  , p=0.5368  , df=2
# parameter F test:         F=0.5055  , p=0.6111  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7087  , p=0.2054  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=7.3686  , p=0.0610  , df=3
# likelihood ratio test: chi2=6.3921  , p=0.0940  , df=3
# parameter F test:         F=1.7087  , p=0.2054  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3761  , p=0.1058  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=16.0843 , p=0.0029  , df=4
# likelihood ratio test: chi2=12.0727 , p=0.0168  , df=4
# parameter F test:         F=2.3761  , p=0.1058  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6883  , p=0.0860  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=28.2276 , p=0.0000  , df=5
# likelihood ratio test: chi2=17.8906 , p=0.0031  , df=5
# parameter F test:         F=2.6883  , p=0.0860  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   strength,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.6748
# 2 	 0.6111
# 3 	 0.2054
# 4 	 0.1058
# 5 	 0.0860★
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0600  , p=0.3144  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.2045  , p=0.2724  , df=1
# likelihood ratio test: chi2=1.1764  , p=0.2781  , df=1
# parameter F test:         F=1.0600  , p=0.3144  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.4573  , p=0.1124  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=6.2080  , p=0.0449  , df=2
# likelihood ratio test: chi2=5.5213  , p=0.0633  , df=2
# parameter F test:         F=2.4573  , p=0.1124  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6743  , p=0.2124  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=7.2203  , p=0.0652  , df=3
# likelihood ratio test: chi2=6.2795  , p=0.0988  , df=3
# parameter F test:         F=1.6743  , p=0.2124  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3288  , p=0.3110  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=8.9950  , p=0.0612  , df=4
# likelihood ratio test: chi2=7.5412  , p=0.1099  , df=4
# parameter F test:         F=1.3288  , p=0.3110  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0603  , p=0.4361  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=11.1336 , p=0.0488  , df=5
# likelihood ratio test: chi2=8.9330  , p=0.1118  , df=5
# parameter F test:         F=1.0603  , p=0.4361  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   strength,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.3144
# 2 	 0.1124
# 3 	 0.2124
# 4 	 0.3110
# 5 	 0.4361
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0239  , p=0.8786  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0271  , p=0.8692  , df=1
# likelihood ratio test: chi2=0.0271  , p=0.8692  , df=1
# parameter F test:         F=0.0239  , p=0.8786  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1398  , p=0.8704  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.3531  , p=0.8381  , df=2
# likelihood ratio test: chi2=0.3506  , p=0.8392  , df=2
# parameter F test:         F=0.1398  , p=0.8704  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2663  , p=0.8487  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=1.1483  , p=0.7654  , df=3
# likelihood ratio test: chi2=1.1206  , p=0.7721  , df=3
# parameter F test:         F=0.2663  , p=0.8487  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1987  , p=0.9346  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=1.3453  , p=0.8536  , df=4
# likelihood ratio test: chi2=1.3058  , p=0.8604  , df=4
# parameter F test:         F=0.1987  , p=0.9346  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9498  , p=0.1726  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=20.4732 , p=0.0010  , df=5
# likelihood ratio test: chi2=14.2910 , p=0.0139  , df=5
# parameter F test:         F=1.9498  , p=0.1726  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   emerging_topic_score,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.8786
# 2 	 0.8704
# 3 	 0.8487
# 4 	 0.9346
# 5 	 0.1726
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1169  , p=0.7357  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.1328  , p=0.7155  , df=1
# likelihood ratio test: chi2=0.1325  , p=0.7159  , df=1
# parameter F test:         F=0.1169  , p=0.7357  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.7874  , p=0.0868  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=7.0419  , p=0.0296  , df=2
# likelihood ratio test: chi2=6.1748  , p=0.0456  , df=2
# parameter F test:         F=2.7874  , p=0.0868  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6328  , p=0.2213  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=7.0413  , p=0.0706  , df=3
# likelihood ratio test: chi2=6.1428  , p=0.1049  , df=3
# parameter F test:         F=1.6328  , p=0.2213  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1007  , p=0.3971  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=7.4509  , p=0.1139  , df=4
# likelihood ratio test: chi2=6.4170  , p=0.1701  , df=4
# parameter F test:         F=1.1007  , p=0.3971  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1117  , p=0.4128  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=11.6726 , p=0.0396  , df=5
# likelihood ratio test: chi2=9.2823  , p=0.0983  , df=5
# parameter F test:         F=1.1117  , p=0.4128  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   emerging_topic_score,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.7357
# 2 	 0.0868★
# 3 	 0.2213
# 4 	 0.3971
# 5 	 0.4128
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4525  , p=0.5081  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.5142  , p=0.4733  , df=1
# likelihood ratio test: chi2=0.5090  , p=0.4756  , df=1
# parameter F test:         F=0.4525  , p=0.5081  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5796  , p=0.5697  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.4642  , p=0.4809  , df=2
# likelihood ratio test: chi2=1.4213  , p=0.4913  , df=2
# parameter F test:         F=0.5796  , p=0.5697  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5862  , p=0.6327  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=2.5281  , p=0.4702  , df=3
# likelihood ratio test: chi2=2.3986  , p=0.4939  , df=3
# parameter F test:         F=0.5862  , p=0.6327  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.7518  , p=0.0738  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=18.6274 , p=0.0009  , df=4
# likelihood ratio test: chi2=13.4948 , p=0.0091  , df=4
# parameter F test:         F=2.7518  , p=0.0738  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8202  , p=0.1965  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=19.1126 , p=0.0018  , df=5
# likelihood ratio test: chi2=13.5905 , p=0.0184  , df=5
# parameter F test:         F=1.8202  , p=0.1965  , df_denom=10, df_num=5
#
#
#  ==========
# djia,   emerging_topic_score,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.5081
# 2 	 0.5697
# 3 	 0.6327
# 4 	 0.0738★
# 5 	 0.1965
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1273  , p=0.7246  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.1447  , p=0.7037  , df=1
# likelihood ratio test: chi2=0.1443  , p=0.7041  , df=1
# parameter F test:         F=0.1273  , p=0.7246  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6154  , p=0.5509  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.5546  , p=0.4596  , df=2
# likelihood ratio test: chi2=1.5064  , p=0.4709  , df=2
# parameter F test:         F=0.6154  , p=0.5509  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2889  , p=0.8328  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=1.2458  , p=0.7420  , df=3
# likelihood ratio test: chi2=1.2132  , p=0.7498  , df=3
# parameter F test:         F=0.2889  , p=0.8328  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0549  , p=0.4171  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=7.1411  , p=0.1286  , df=4
# likelihood ratio test: chi2=6.1844  , p=0.1858  , df=4
# parameter F test:         F=1.0549  , p=0.4171  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8506  , p=0.1906  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=19.4318 , p=0.0016  , df=5
# likelihood ratio test: chi2=13.7570 , p=0.0172  , df=5
# parameter F test:         F=1.8506  , p=0.1906  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   frequency,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.7246
# 2 	 0.5509
# 3 	 0.8328
# 4 	 0.4171
# 5 	 0.1906
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0000  , p=0.9984  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0000  , p=0.9983  , df=1
# likelihood ratio test: chi2=0.0000  , p=0.9983  , df=1
# parameter F test:         F=0.0000  , p=0.9984  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0137  , p=0.9864  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.0347  , p=0.9828  , df=2
# likelihood ratio test: chi2=0.0347  , p=0.9828  , df=2
# parameter F test:         F=0.0137  , p=0.9864  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8797  , p=0.4723  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=3.7939  , p=0.2846  , df=3
# likelihood ratio test: chi2=3.5116  , p=0.3193  , df=3
# parameter F test:         F=0.8797  , p=0.4723  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6735  , p=0.6220  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=4.5593  , p=0.3356  , df=4
# likelihood ratio test: chi2=4.1434  , p=0.3869  , df=4
# parameter F test:         F=0.6735  , p=0.6220  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9976  , p=0.1646  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=20.9744 , p=0.0008  , df=5
# likelihood ratio test: chi2=14.5433 , p=0.0125  , df=5
# parameter F test:         F=1.9976  , p=0.1646  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   frequency,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.9984
# 2 	 0.9864
# 3 	 0.4723
# 4 	 0.6220
# 5 	 0.1646
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5916  , p=0.2203  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.8087  , p=0.1787  , df=1
# likelihood ratio test: chi2=1.7462  , p=0.1864  , df=1
# parameter F test:         F=1.5916  , p=0.2203  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8755  , p=0.4328  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=2.2117  , p=0.3309  , df=2
# likelihood ratio test: chi2=2.1157  , p=0.3472  , df=2
# parameter F test:         F=0.8755  , p=0.4328  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9439  , p=0.4427  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=4.0704  , p=0.2540  , df=3
# likelihood ratio test: chi2=3.7478  , p=0.2900  , df=3
# parameter F test:         F=0.9439  , p=0.4427  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8029  , p=0.5447  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=5.4350  , p=0.2455  , df=4
# likelihood ratio test: chi2=4.8571  , p=0.3023  , df=4
# parameter F test:         F=0.8029  , p=0.5447  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6431  , p=0.6730  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=6.7527  , p=0.2397  , df=5
# likelihood ratio test: chi2=5.8550  , p=0.3206  , df=5
# parameter F test:         F=0.6431  , p=0.6730  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   frequency,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.2203
# 2 	 0.4328
# 3 	 0.4427
# 4 	 0.5447
# 5 	 0.6730
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1215  , p=0.7308  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.1380  , p=0.7103  , df=1
# likelihood ratio test: chi2=0.1376  , p=0.7106  , df=1
# parameter F test:         F=0.1215  , p=0.7308  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5289  , p=0.2423  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=3.8624  , p=0.1450  , df=2
# likelihood ratio test: chi2=3.5814  , p=0.1668  , df=2
# parameter F test:         F=1.5289  , p=0.2423  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7967  , p=0.5136  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=3.4357  , p=0.3292  , df=3
# likelihood ratio test: chi2=3.2020  , p=0.3615  , df=3
# parameter F test:         F=0.7967  , p=0.5136  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8363  , p=0.5260  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=5.6608  , p=0.2260  , df=4
# likelihood ratio test: chi2=5.0374  , p=0.2835  , df=4
# parameter F test:         F=0.8363  , p=0.5260  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3773  , p=0.8532  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=3.9620  , p=0.5549  , df=5
# likelihood ratio test: chi2=3.6295  , p=0.6039  , df=5
# parameter F test:         F=0.3773  , p=0.8532  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   strength,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.7308
# 2 	 0.2423
# 3 	 0.5136
# 4 	 0.5260
# 5 	 0.8532
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6037  , p=0.2186  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.8224  , p=0.1770  , df=1
# likelihood ratio test: chi2=1.7591  , p=0.1847  , df=1
# parameter F test:         F=1.6037  , p=0.2186  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0692  , p=0.3631  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=2.7011  , p=0.2591  , df=2
# likelihood ratio test: chi2=2.5596  , p=0.2781  , df=2
# parameter F test:         F=1.0692  , p=0.3631  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9972  , p=0.1550  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=8.6128  , p=0.0349  , df=3
# likelihood ratio test: chi2=7.3156  , p=0.0625  , df=3
# parameter F test:         F=1.9972  , p=0.1550  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.6995  , p=0.0145  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=31.8117 , p=0.0000  , df=4
# likelihood ratio test: chi2=19.6779 , p=0.0006  , df=4
# parameter F test:         F=4.6995  , p=0.0145  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.3443  , p=0.0493  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=35.1155 , p=0.0000  , df=5
# likelihood ratio test: chi2=20.6407 , p=0.0009  , df=5
# parameter F test:         F=3.3443  , p=0.0493  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   strength,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.2186
# 2 	 0.3631
# 3 	 0.1550
# 4 	 0.0145★
# 5 	 0.0493★
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0341  , p=0.8551  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0388  , p=0.8439  , df=1
# likelihood ratio test: chi2=0.0387  , p=0.8440  , df=1
# parameter F test:         F=0.0341  , p=0.8551  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4800  , p=0.6261  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.2125  , p=0.5454  , df=2
# likelihood ratio test: chi2=1.1829  , p=0.5535  , df=2
# parameter F test:         F=0.4800  , p=0.6261  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2044  , p=0.3400  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=5.1939  , p=0.1581  , df=3
# likelihood ratio test: chi2=4.6831  , p=0.1965  , df=3
# parameter F test:         F=1.2044  , p=0.3400  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9210  , p=0.4811  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=6.2342  , p=0.1823  , df=4
# likelihood ratio test: chi2=5.4888  , p=0.2407  , df=4
# parameter F test:         F=0.9210  , p=0.4811  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3882  , p=0.8460  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=4.0761  , p=0.5385  , df=5
# likelihood ratio test: chi2=3.7253  , p=0.5896  , df=5
# parameter F test:         F=0.3882  , p=0.8460  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   strength,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.8551
# 2 	 0.6261
# 3 	 0.3400
# 4 	 0.4811
# 5 	 0.8460
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3562  , p=0.5567  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.4047  , p=0.5247  , df=1
# likelihood ratio test: chi2=0.4015  , p=0.5263  , df=1
# parameter F test:         F=0.3562  , p=0.5567  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6009  , p=0.1004  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=6.5706  , p=0.0374  , df=2
# likelihood ratio test: chi2=5.8077  , p=0.0548  , df=2
# parameter F test:         F=2.6009  , p=0.1004  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.9282  , p=0.0130  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=21.2529 , p=0.0001  , df=3
# likelihood ratio test: chi2=15.0518 , p=0.0018  , df=3
# parameter F test:         F=4.9282  , p=0.0130  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2198  , p=0.1234  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=15.0263 , p=0.0046  , df=4
# likelihood ratio test: chi2=11.4529 , p=0.0219  , df=4
# parameter F test:         F=2.2198  , p=0.1234  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5496  , p=0.2595  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=16.2705 , p=0.0061  , df=5
# likelihood ratio test: chi2=12.0473 , p=0.0341  , df=5
# parameter F test:         F=1.5496  , p=0.2595  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   emerging_topic_score,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.5567
# 2 	 0.1004
# 3 	 0.0130★
# 4 	 0.1234
# 5 	 0.2595
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0758  , p=0.7856  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0862  , p=0.7691  , df=1
# likelihood ratio test: chi2=0.0860  , p=0.7693  , df=1
# parameter F test:         F=0.0758  , p=0.7856  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1265  , p=0.8819  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.3197  , p=0.8523  , df=2
# likelihood ratio test: chi2=0.3176  , p=0.8532  , df=2
# parameter F test:         F=0.1265  , p=0.8819  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3446  , p=0.7934  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=1.4863  , p=0.6854  , df=3
# likelihood ratio test: chi2=1.4402  , p=0.6961  , df=3
# parameter F test:         F=0.3446  , p=0.7934  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.0182  , p=0.1511  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=13.6618 , p=0.0085  , df=4
# likelihood ratio test: chi2=10.6268 , p=0.0311  , df=4
# parameter F test:         F=2.0182  , p=0.1511  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.3984  , p=0.0223  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=46.1831 , p=0.0000  , df=5
# likelihood ratio test: chi2=24.4209 , p=0.0002  , df=5
# parameter F test:         F=4.3984  , p=0.0223  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   emerging_topic_score,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.7856
# 2 	 0.8819
# 3 	 0.7934
# 4 	 0.1511
# 5 	 0.0223★
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3208  , p=0.2628  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.5009  , p=0.2205  , df=1
# likelihood ratio test: chi2=1.4576  , p=0.2273  , df=1
# parameter F test:         F=1.3208  , p=0.2628  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0589  , p=0.3664  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=2.6752  , p=0.2625  , df=2
# likelihood ratio test: chi2=2.5363  , p=0.2813  , df=2
# parameter F test:         F=1.0589  , p=0.3664  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6128  , p=0.6165  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=2.6429  , p=0.4500  , df=3
# likelihood ratio test: chi2=2.5017  , p=0.4750  , df=3
# parameter F test:         F=0.6128  , p=0.6165  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3905  , p=0.8118  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=2.6435  , p=0.6191  , df=4
# likelihood ratio test: chi2=2.4963  , p=0.6453  , df=4
# parameter F test:         F=0.3905  , p=0.8118  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3009  , p=0.9014  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=3.1595  , p=0.6754  , df=5
# likelihood ratio test: chi2=2.9432  , p=0.7087  , df=5
# parameter F test:         F=0.3009  , p=0.9014  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment_not_adjusted,   emerging_topic_score,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.2628
# 2 	 0.3664
# 3 	 0.6165
# 4 	 0.8118
# 5 	 0.9014
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0197  , p=0.1693  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=2.2951  , p=0.1298  , df=1
# likelihood ratio test: chi2=2.1958  , p=0.1384  , df=1
# parameter F test:         F=2.0197  , p=0.1693  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9914  , p=0.3895  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=2.5045  , p=0.2859  , df=2
# likelihood ratio test: chi2=2.3823  , p=0.3039  , df=2
# parameter F test:         F=0.9914  , p=0.3895  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2899  , p=0.8320  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=1.2502  , p=0.7410  , df=3
# likelihood ratio test: chi2=1.2174  , p=0.7488  , df=3
# parameter F test:         F=0.2899  , p=0.8320  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2993  , p=0.3209  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=8.7952  , p=0.0664  , df=4
# likelihood ratio test: chi2=7.3990  , p=0.1162  , df=4
# parameter F test:         F=1.2993  , p=0.3209  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0178  , p=0.4564  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=10.6870 , p=0.0580  , df=5
# likelihood ratio test: chi2=8.6391  , p=0.1244  , df=5
# parameter F test:         F=1.0178  , p=0.4564  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   frequency,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.1693
# 2 	 0.3895
# 3 	 0.8320
# 4 	 0.3209
# 5 	 0.4564
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6378  , p=0.4330  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.7248  , p=0.3946  , df=1
# likelihood ratio test: chi2=0.7145  , p=0.3980  , df=1
# parameter F test:         F=0.6378  , p=0.4330  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9879  , p=0.3907  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=2.4957  , p=0.2871  , df=2
# likelihood ratio test: chi2=2.3743  , p=0.3051  , df=2
# parameter F test:         F=0.9879  , p=0.3907  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9125  , p=0.4570  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=3.9350  , p=0.2686  , df=3
# likelihood ratio test: chi2=3.6325  , p=0.3040  , df=3
# parameter F test:         F=0.9125  , p=0.4570  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0331  , p=0.4269  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=6.9935  , p=0.1362  , df=4
# likelihood ratio test: chi2=6.0727  , p=0.1938  , df=4
# parameter F test:         F=1.0331  , p=0.4269  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5200  , p=0.2676  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=15.9605 , p=0.0070  , df=5
# likelihood ratio test: chi2=11.8719 , p=0.0366  , df=5
# parameter F test:         F=1.5200  , p=0.2676  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   frequency,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.4330
# 2 	 0.3907
# 3 	 0.4570
# 4 	 0.4269
# 5 	 0.2676
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7499  , p=0.3958  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.8522  , p=0.3559  , df=1
# likelihood ratio test: chi2=0.8380  , p=0.3600  , df=1
# parameter F test:         F=0.7499  , p=0.3958  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3527  , p=0.7073  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.8909  , p=0.6405  , df=2
# likelihood ratio test: chi2=0.8748  , p=0.6457  , df=2
# parameter F test:         F=0.3527  , p=0.7073  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3818  , p=0.7675  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=1.6467  , p=0.6489  , df=3
# likelihood ratio test: chi2=1.5904  , p=0.6616  , df=3
# parameter F test:         F=0.3818  , p=0.7675  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5902  , p=0.6757  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=3.9949  , p=0.4067  , df=4
# likelihood ratio test: chi2=3.6709  , p=0.4524  , df=4
# parameter F test:         F=0.5902  , p=0.6757  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6095  , p=0.6953  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=6.4000  , p=0.2692  , df=5
# likelihood ratio test: chi2=5.5865  , p=0.3486  , df=5
# parameter F test:         F=0.6095  , p=0.6953  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   frequency,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.3958
# 2 	 0.7073
# 3 	 0.7675
# 4 	 0.6757
# 5 	 0.6953
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.1450  , p=0.0900  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=3.5739  , p=0.0587  , df=1
# likelihood ratio test: chi2=3.3404  , p=0.0676  , df=1
# parameter F test:         F=3.1450  , p=0.0900  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3043  , p=0.1271  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=5.8214  , p=0.0544  , df=2
# likelihood ratio test: chi2=5.2122  , p=0.0738  , df=2
# parameter F test:         F=2.3043  , p=0.1271  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5350  , p=0.6649  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=2.3074  , p=0.5111  , df=3
# likelihood ratio test: chi2=2.1988  , p=0.5322  , df=3
# parameter F test:         F=0.5350  , p=0.6649  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6151  , p=0.6594  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=4.1636  , p=0.3843  , df=4
# likelihood ratio test: chi2=3.8132  , p=0.4319  , df=4
# parameter F test:         F=0.6151  , p=0.6594  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4009  , p=0.8376  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=4.2091  , p=0.5197  , df=5
# likelihood ratio test: chi2=3.8363  , p=0.5732  , df=5
# parameter F test:         F=0.4009  , p=0.8376  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   strength,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.0900★
# 2 	 0.1271
# 3 	 0.6649
# 4 	 0.6594
# 5 	 0.8376
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0256  , p=0.8744  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0291  , p=0.8646  , df=1
# likelihood ratio test: chi2=0.0290  , p=0.8647  , df=1
# parameter F test:         F=0.0256  , p=0.8744  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4474  , p=0.2600  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=3.6566  , p=0.1607  , df=2
# likelihood ratio test: chi2=3.4034  , p=0.1824  , df=2
# parameter F test:         F=1.4474  , p=0.2600  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8968  , p=0.0289  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=16.8048 , p=0.0008  , df=3
# likelihood ratio test: chi2=12.6153 , p=0.0055  , df=3
# parameter F test:         F=3.8968  , p=0.0289  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.5441  , p=0.0163  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=30.7598 , p=0.0000  , df=4
# likelihood ratio test: chi2=19.2436 , p=0.0007  , df=4
# parameter F test:         F=4.5441  , p=0.0163  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=5.3480  , p=0.0119  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=56.1545 , p=0.0000  , df=5
# likelihood ratio test: chi2=27.3270 , p=0.0000  , df=5
# parameter F test:         F=5.3480  , p=0.0119  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   strength,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.8744
# 2 	 0.2600
# 3 	 0.0289★
# 4 	 0.0163★
# 5 	 0.0119★
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2976  , p=0.5909  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.3381  , p=0.5609  , df=1
# likelihood ratio test: chi2=0.3359  , p=0.5622  , df=1
# parameter F test:         F=0.2976  , p=0.5909  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3870  , p=0.6844  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.9776  , p=0.6134  , df=2
# likelihood ratio test: chi2=0.9582  , p=0.6193  , df=2
# parameter F test:         F=0.3870  , p=0.6844  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5759  , p=0.6391  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=2.4837  , p=0.4783  , df=3
# likelihood ratio test: chi2=2.3585  , p=0.5014  , df=3
# parameter F test:         F=0.5759  , p=0.6391  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5222  , p=0.7213  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=3.5346  , p=0.4726  , df=4
# likelihood ratio test: chi2=3.2778  , p=0.5125  , df=4
# parameter F test:         F=0.5222  , p=0.7213  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6938  , p=0.6400  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=7.2848  , p=0.2003  , df=5
# likelihood ratio test: chi2=6.2539  , p=0.2823  , df=5
# parameter F test:         F=0.6938  , p=0.6400  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   strength,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.5909
# 2 	 0.6844
# 3 	 0.6391
# 4 	 0.7213
# 5 	 0.6400
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0024  , p=0.9616  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0027  , p=0.9586  , df=1
# likelihood ratio test: chi2=0.0027  , p=0.9586  , df=1
# parameter F test:         F=0.0024  , p=0.9616  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3070  , p=0.7392  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.7757  , p=0.6785  , df=2
# likelihood ratio test: chi2=0.7634  , p=0.6827  , df=2
# parameter F test:         F=0.3070  , p=0.7392  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0176  , p=0.4108  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=4.3885  , p=0.2225  , df=3
# likelihood ratio test: chi2=4.0164  , p=0.2597  , df=3
# parameter F test:         F=1.0176  , p=0.4108  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5577  , p=0.6973  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=3.7754  , p=0.4373  , df=4
# likelihood ratio test: chi2=3.4843  , p=0.4803  , df=4
# parameter F test:         F=0.5577  , p=0.6973  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0607  , p=0.1547  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=21.6373 , p=0.0006  , df=5
# likelihood ratio test: chi2=14.8724 , p=0.0109  , df=5
# parameter F test:         F=2.0607  , p=0.1547  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   emerging_topic_score,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.9616
# 2 	 0.7392
# 3 	 0.4108
# 4 	 0.6973
# 5 	 0.1547
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8886  , p=0.3561  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.0098  , p=0.3150  , df=1
# likelihood ratio test: chi2=0.9899  , p=0.3198  , df=1
# parameter F test:         F=0.8886  , p=0.3561  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3930  , p=0.6804  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.9927  , p=0.6087  , df=2
# likelihood ratio test: chi2=0.9727  , p=0.6149  , df=2
# parameter F test:         F=0.3930  , p=0.6804  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1572  , p=0.3566  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=4.9906  , p=0.1725  , df=3
# likelihood ratio test: chi2=4.5166  , p=0.2108  , df=3
# parameter F test:         F=1.1572  , p=0.3566  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0749  , p=0.4083  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=7.2764  , p=0.1220  , df=4
# likelihood ratio test: chi2=6.2863  , p=0.1788  , df=4
# parameter F test:         F=1.0749  , p=0.4083  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6240  , p=0.6857  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=6.5516  , p=0.2562  , df=5
# likelihood ratio test: chi2=5.7023  , p=0.3363  , df=5
# parameter F test:         F=0.6240  , p=0.6857  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   emerging_topic_score,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.3561
# 2 	 0.6804
# 3 	 0.3566
# 4 	 0.4083
# 5 	 0.6857
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0023  , p=0.9620  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0026  , p=0.9590  , df=1
# likelihood ratio test: chi2=0.0026  , p=0.9590  , df=1
# parameter F test:         F=0.0023  , p=0.9620  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7812  , p=0.4720  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.9736  , p=0.3728  , df=2
# likelihood ratio test: chi2=1.8967  , p=0.3874  , df=2
# parameter F test:         F=0.7812  , p=0.4720  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3459  , p=0.2948  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=5.8041  , p=0.1215  , df=3
# likelihood ratio test: chi2=5.1755  , p=0.1594  , df=3
# parameter F test:         F=1.3459  , p=0.2948  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.3936  , p=0.0414  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=22.9721 , p=0.0001  , df=4
# likelihood ratio test: chi2=15.7300 , p=0.0034  , df=4
# parameter F test:         F=3.3936  , p=0.0414  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.4921  , p=0.1027  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=26.1671 , p=0.0001  , df=5
# likelihood ratio test: chi2=16.9927 , p=0.0045  , df=5
# parameter F test:         F=2.4921  , p=0.1027  , df_denom=10, df_num=5
#
#
#  ==========
# unemployment,   emerging_topic_score,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.9620
# 2 	 0.4720
# 3 	 0.2948
# 4 	 0.0414★
# 5 	 0.1027
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2699  , p=0.6086  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.3068  , p=0.5797  , df=1
# likelihood ratio test: chi2=0.3049  , p=0.5808  , df=1
# parameter F test:         F=0.2699  , p=0.6086  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0131  , p=0.3819  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=2.5594  , p=0.2781  , df=2
# likelihood ratio test: chi2=2.4319  , p=0.2964  , df=2
# parameter F test:         F=1.0131  , p=0.3819  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5199  , p=0.6746  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=2.2420  , p=0.5237  , df=3
# likelihood ratio test: chi2=2.1393  , p=0.5440  , df=3
# parameter F test:         F=0.5199  , p=0.6746  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3086  , p=0.8671  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=2.0888  , p=0.7194  , df=4
# likelihood ratio test: chi2=1.9955  , p=0.7366  , df=4
# parameter F test:         F=0.3086  , p=0.8671  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6818  , p=0.6477  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=7.1590  , p=0.2091  , df=5
# likelihood ratio test: chi2=6.1602  , p=0.2909  , df=5
# parameter F test:         F=0.6818  , p=0.6477  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   frequency,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.6086
# 2 	 0.3819
# 3 	 0.6746
# 4 	 0.8671
# 5 	 0.6477
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3705  , p=0.5490  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.4210  , p=0.5165  , df=1
# likelihood ratio test: chi2=0.4175  , p=0.5182  , df=1
# parameter F test:         F=0.3705  , p=0.5490  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4798  , p=0.2528  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=3.7385  , p=0.1542  , df=2
# likelihood ratio test: chi2=3.4744  , p=0.1760  , df=2
# parameter F test:         F=1.4798  , p=0.2528  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1792  , p=0.3488  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=5.0855  , p=0.1656  , df=3
# likelihood ratio test: chi2=4.5944  , p=0.2040  , df=3
# parameter F test:         F=1.1792  , p=0.3488  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7928  , p=0.5505  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=5.3667  , p=0.2517  , df=4
# likelihood ratio test: chi2=4.8022  , p=0.3082  , df=4
# parameter F test:         F=0.7928  , p=0.5505  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0450  , p=0.4433  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=10.9729 , p=0.0519  , df=5
# likelihood ratio test: chi2=8.8277  , p=0.1161  , df=5
# parameter F test:         F=1.0450  , p=0.4433  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   frequency,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.5490
# 2 	 0.2528
# 3 	 0.3488
# 4 	 0.5505
# 5 	 0.4433
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9055  , p=0.3517  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.0290  , p=0.3104  , df=1
# likelihood ratio test: chi2=1.0084  , p=0.3153  , df=1
# parameter F test:         F=0.9055  , p=0.3517  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4778  , p=0.6274  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.2070  , p=0.5469  , df=2
# likelihood ratio test: chi2=1.1776  , p=0.5550  , df=2
# parameter F test:         F=0.4778  , p=0.6274  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2531  , p=0.8580  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=1.0914  , p=0.7792  , df=3
# likelihood ratio test: chi2=1.0663  , p=0.7852  , df=3
# parameter F test:         F=0.2531  , p=0.8580  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1986  , p=0.9347  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=1.3441  , p=0.8538  , df=4
# likelihood ratio test: chi2=1.3046  , p=0.8606  , df=4
# parameter F test:         F=0.1986  , p=0.9347  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.0914  , p=0.9918  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=0.9593  , p=0.9658  , df=5
# likelihood ratio test: chi2=0.9380  , p=0.9674  , df=5
# parameter F test:         F=0.0914  , p=0.9918  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   frequency,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.3517
# 2 	 0.6274
# 3 	 0.8580
# 4 	 0.9347
# 5 	 0.9918
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0082  , p=0.9287  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0093  , p=0.9231  , df=1
# likelihood ratio test: chi2=0.0093  , p=0.9231  , df=1
# parameter F test:         F=0.0082  , p=0.9287  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3277  , p=0.1247  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=5.8806  , p=0.0528  , df=2
# likelihood ratio test: chi2=5.2597  , p=0.0721  , df=2
# parameter F test:         F=2.3277  , p=0.1247  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9688  , p=0.1594  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=8.4904  , p=0.0369  , df=3
# likelihood ratio test: chi2=7.2263  , p=0.0650  , df=3
# parameter F test:         F=1.9688  , p=0.1594  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0879  , p=0.4026  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=7.3640  , p=0.1179  , df=4
# likelihood ratio test: chi2=6.3520  , p=0.1744  , df=4
# parameter F test:         F=1.0879  , p=0.4026  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1859  , p=0.3813  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=12.4514 , p=0.0291  , df=5
# likelihood ratio test: chi2=9.7770  , p=0.0818  , df=5
# parameter F test:         F=1.1859  , p=0.3813  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   strength,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.9287
# 2 	 0.1247
# 3 	 0.1594
# 4 	 0.4026
# 5 	 0.3813
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4275  , p=0.5200  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.4858  , p=0.4858  , df=1
# likelihood ratio test: chi2=0.4812  , p=0.4879  , df=1
# parameter F test:         F=0.4275  , p=0.5200  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6974  , p=0.5102  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.7618  , p=0.4144  , df=2
# likelihood ratio test: chi2=1.7001  , p=0.4274  , df=2
# parameter F test:         F=0.6974  , p=0.5102  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8355  , p=0.1814  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=7.9155  , p=0.0478  , df=3
# likelihood ratio test: chi2=6.8026  , p=0.0785  , df=3
# parameter F test:         F=1.8355  , p=0.1814  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5269  , p=0.2518  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=10.3361 , p=0.0351  , df=4
# likelihood ratio test: chi2=8.4731  , p=0.0757  , df=4
# parameter F test:         F=1.5269  , p=0.2518  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0656  , p=0.1539  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=21.6893 , p=0.0006  , df=5
# likelihood ratio test: chi2=14.8979 , p=0.0108  , df=5
# parameter F test:         F=2.0656  , p=0.1539  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   strength,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.5200
# 2 	 0.5102
# 3 	 0.1814
# 4 	 0.2518
# 5 	 0.1539
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7784  , p=0.3872  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.8846  , p=0.3470  , df=1
# likelihood ratio test: chi2=0.8693  , p=0.3512  , df=1
# parameter F test:         F=0.7784  , p=0.3872  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8098  , p=0.1908  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=4.5721  , p=0.1017  , df=2
# likelihood ratio test: chi2=4.1850  , p=0.1234  , df=2
# parameter F test:         F=1.8098  , p=0.1908  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5217  , p=0.2472  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=6.5622  , p=0.0872  , df=3
# likelihood ratio test: chi2=5.7730  , p=0.1232  , df=3
# parameter F test:         F=1.5217  , p=0.2472  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0831  , p=0.4047  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=7.3316  , p=0.1194  , df=4
# likelihood ratio test: chi2=6.3277  , p=0.1760  , df=4
# parameter F test:         F=1.0831  , p=0.4047  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5711  , p=0.7213  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=5.9969  , p=0.3065  , df=5
# likelihood ratio test: chi2=5.2752  , p=0.3832  , df=5
# parameter F test:         F=0.5711  , p=0.7213  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   strength,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.3872
# 2 	 0.1908
# 3 	 0.2472
# 4 	 0.4047
# 5 	 0.7213
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7138  , p=0.4073  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.8112  , p=0.3678  , df=1
# likelihood ratio test: chi2=0.7983  , p=0.3716  , df=1
# parameter F test:         F=0.7138  , p=0.4073  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4996  , p=0.6145  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.2621  , p=0.5320  , df=2
# likelihood ratio test: chi2=1.2301  , p=0.5406  , df=2
# parameter F test:         F=0.4996  , p=0.6145  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7196  , p=0.5547  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=3.1034  , p=0.3760  , df=3
# likelihood ratio test: chi2=2.9112  , p=0.4055  , df=3
# parameter F test:         F=0.7196  , p=0.5547  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1116  , p=0.3925  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=7.5250  , p=0.1106  , df=4
# likelihood ratio test: chi2=6.4723  , p=0.1665  , df=4
# parameter F test:         F=1.1116  , p=0.3925  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4066  , p=0.8337  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=4.2693  , p=0.5113  , df=5
# likelihood ratio test: chi2=3.8864  , p=0.5659  , df=5
# parameter F test:         F=0.4066  , p=0.8337  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   emerging_topic_score,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.4073
# 2 	 0.6145
# 3 	 0.5547
# 4 	 0.3925
# 5 	 0.8337
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0823  , p=0.7768  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=0.0936  , p=0.7597  , df=1
# likelihood ratio test: chi2=0.0934  , p=0.7599  , df=1
# parameter F test:         F=0.0823  , p=0.7768  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7020  , p=0.5080  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.7734  , p=0.4120  , df=2
# likelihood ratio test: chi2=1.7110  , p=0.4251  , df=2
# parameter F test:         F=0.7020  , p=0.5080  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6462  , p=0.5966  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=2.7866  , p=0.4257  , df=3
# likelihood ratio test: chi2=2.6303  , p=0.4522  , df=3
# parameter F test:         F=0.6462  , p=0.5966  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8888  , p=0.1725  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=12.7858 , p=0.0124  , df=4
# likelihood ratio test: chi2=10.0796 , p=0.0391  , df=4
# parameter F test:         F=1.8888  , p=0.1725  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9751  , p=0.4776  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=10.2388 , p=0.0687  , df=5
# likelihood ratio test: chi2=8.3399  , p=0.1385  , df=5
# parameter F test:         F=0.9751  , p=0.4776  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   emerging_topic_score,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.7768
# 2 	 0.5080
# 3 	 0.5966
# 4 	 0.1725
# 5 	 0.4776
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0192  , p=0.3237  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.1582  , p=0.2818  , df=1
# likelihood ratio test: chi2=1.1321  , p=0.2873  , df=1
# parameter F test:         F=1.0192  , p=0.3237  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3959  , p=0.6785  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=1.0002  , p=0.6065  , df=2
# likelihood ratio test: chi2=0.9799  , p=0.6127  , df=2
# parameter F test:         F=0.3959  , p=0.6785  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2096  , p=0.8882  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=0.9040  , p=0.8245  , df=3
# likelihood ratio test: chi2=0.8867  , p=0.8286  , df=3
# parameter F test:         F=0.2096  , p=0.8882  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2182  , p=0.9236  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=1.4767  , p=0.8308  , df=4
# likelihood ratio test: chi2=1.4293  , p=0.8391  , df=4
# parameter F test:         F=0.2182  , p=0.9236  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.1995  , p=0.9554  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=2.0951  , p=0.8358  , df=5
# likelihood ratio test: chi2=1.9970  , p=0.8496  , df=5
# parameter F test:         F=0.1995  , p=0.9554  , df_denom=10, df_num=5
#
#
#  ==========
# gdp,   emerging_topic_score,   test_period=3
# ==========
# n_lag 	 p-value
# 1 	 0.3237
# 2 	 0.6785
# 3 	 0.8882
# 4 	 0.9236
# 5 	 0.9554
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0174  , p=0.3241  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=1.1561  , p=0.2823  , df=1
# likelihood ratio test: chi2=1.1302  , p=0.2877  , df=1
# parameter F test:         F=1.0174  , p=0.3241  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2600  , p=0.3063  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=3.1831  , p=0.2036  , df=2
# likelihood ratio test: chi2=2.9890  , p=0.2244  , df=2
# parameter F test:         F=1.2600  , p=0.3063  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4460  , p=0.2666  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=6.2357  , p=0.1007  , df=3
# likelihood ratio test: chi2=5.5176  , p=0.1376  , df=3
# parameter F test:         F=1.4460  , p=0.2666  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9506  , p=0.1619  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=13.2040 , p=0.0103  , df=4
# likelihood ratio test: chi2=10.3426 , p=0.0350  , df=4
# parameter F test:         F=1.9506  , p=0.1619  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2137  , p=0.3702  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=12.7435 , p=0.0259  , df=5
# likelihood ratio test: chi2=9.9596  , p=0.0764  , df=5
# parameter F test:         F=1.2137  , p=0.3702  , df_denom=10, df_num=5
#
#
#  ==========
# interest_rate,   frequency,   test_period=1
# ==========
# n_lag 	 p-value
# 1 	 0.3241
# 2 	 0.3063
# 3 	 0.2666
# 4 	 0.1619
# 5 	 0.3702
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8616  , p=0.1862  , df_denom=22, df_num=1
# ssr based chi2 test:   chi2=2.1154  , p=0.1458  , df=1
# likelihood ratio test: chi2=2.0307  , p=0.1542  , df=1
# parameter F test:         F=1.8616  , p=0.1862  , df_denom=22, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2375  , p=0.7909  , df_denom=19, df_num=2
# ssr based chi2 test:   chi2=0.6000  , p=0.7408  , df=2
# likelihood ratio test: chi2=0.5926  , p=0.7436  , df=2
# parameter F test:         F=0.2375  , p=0.7909  , df_denom=19, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5824  , p=0.6351  , df_denom=16, df_num=3
# ssr based chi2 test:   chi2=2.5116  , p=0.4732  , df=3
# likelihood ratio test: chi2=2.3837  , p=0.4967  , df=3
# parameter F test:         F=0.5824  , p=0.6351  , df_denom=16, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9590  , p=0.4621  , df_denom=13, df_num=4
# ssr based chi2 test:   chi2=6.4915  , p=0.1653  , df=4
# likelihood ratio test: chi2=5.6884  , p=0.2237  , df=4
# parameter F test:         F=0.9590  , p=0.4621  , df_denom=13, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4300  , p=0.2942  , df_denom=10, df_num=5
# ssr based chi2 test:   chi2=15.0154 , p=0.0103  , df=5
# likelihood ratio test: chi2=11.3279 , p=0.0453  , df=5
# parameter F test:         F=1.4300  , p=0.2942  , df_denom=10, df_num=5
#
#
#  ==========
# interest_rate,   frequency,   test_period=2
# ==========
# n_lag 	 p-value
# 1 	 0.1862
# 2 	 0.7909
# 3 	 0.6351
# 4 	 0.4621
# 5 	 0.2942
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-228-039e01bbded3> in <module>()
#      12             x_label = 'standardized: -(sum of top5 ' + i +' )'
#      13             y_label = 'standardized: Real '+ index_name +' (Percent Change)'
# ---> 14             df = show_plt_chart_rolling(x_, y_, x_ticks_list, rolling_window, x_label, y_label, max_lag=max_lag, with_legend=False, show=False)
#      15
#      16             print('\n\n','='*10)
#
# <ipython-input-178-3d00d793268f> in show_plt_chart_rolling(x_, y_, x_ticks_list, rolling_window, x_label, y_label, max_lag, with_legend, show)
#      23     y_normalized_df = y_normalized
#      24     df = pd.concat([y_normalized_df, x_normalized_df], axis=1)   # the predictor (X) is in the second column.
# ---> 25     return grangercausalitytests(df, maxlag=max_lag)
#      26
#      27 plt.rcParams["figure.figsize"] = (20,5)
#
# /home/dmlab/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in grangercausalitytests(x, maxlag, addconst, verbose)
#     846         raise ValueError("Insufficient observations. Maximum allowable "
#     847                          "lag is {0}".format(int((x.shape[0] - int(addconst)) /
# --> 848                                                  3) - 1))
#     849
#     850     resli = {}
#
# ValueError: Insufficient observations. Maximum allowable lag is 0

# %%
to_check_list
# Out:
# ['djia,   frequency,   test_period=3',
#  'djia,   frequency,   test_period=3',
#  'djia,   strength,   test_period=2',
#  'djia,   emerging_topic_score,   test_period=2',
#  'djia,   emerging_topic_score,   test_period=3',
#  'unemployment_not_adjusted,   strength,   test_period=2',
#  'unemployment_not_adjusted,   strength,   test_period=2',
#  'unemployment_not_adjusted,   emerging_topic_score,   test_period=1',
#  'unemployment_not_adjusted,   emerging_topic_score,   test_period=2',
#  'unemployment,   strength,   test_period=1',
#  'unemployment,   strength,   test_period=2',
#  'unemployment,   strength,   test_period=2',
#  'unemployment,   strength,   test_period=2',
#  'unemployment,   emerging_topic_score,   test_period=3']

# %%
'djia,   emerging_topic_score,   test_period=2',
'djia,   emerging_topic_score,   test_period=3',

'unemployment_not_adjusted,   emerging_topic_score,   test_period=1',
'unemployment_not_adjusted,   emerging_topic_score,   test_period=2',

'unemployment,   strength,   test_period=1',
'unemployment,   strength,   test_period=2',
'unemployment,   strength,   test_period=2',
'unemployment,   strength,   test_period=2',

# %%
index_name = 'djia'
i = 'frequency'
s_, e_ = 28, 84

x_ = proposed_data_x_dict[i][index_name][s_:e_]
y_ = fred_data_y_dict[index_name][s_:e_]
x_ticks_list = period_dict[index_name][s_:e_]
x_label = 'standardized: -(sum of top5 ' + i +' )'
y_label = 'standardized: Real '+ index_name +' (Percent Change)'
df = show_plt_chart_rolling(x_, y_, x_ticks_list, rolling_window, x_label, y_label, max_lag=max_lag, with_legend=False, show=False)

print('\n\n','='*10)
title = index_name + ',   ' + str(i) + ',   test_period=' + str(test_key)
print('='*10)
print('n_lag \t p-value')
for n_lag in range(1, max_lag+1):
    p_value_str = '%.4f' % df[n_lag][0]['params_ftest'][1]
    if float(p_value_str) < 0.1:
        p_value_str += '★'
        to_check_list.append(title)
    elif float(p_value_str) < 0.05:
        p_value_str += '★★'
        to_check_list.append(title)
    print('%d \t %s'% (n_lag, p_value_str))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9859  , p=0.3255  , df_denom=50, df_num=1
# ssr based chi2 test:   chi2=1.0451  , p=0.3066  , df=1
# likelihood ratio test: chi2=1.0349  , p=0.3090  , df=1
# parameter F test:         F=0.9859  , p=0.3255  , df_denom=50, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3607  , p=0.2664  , df_denom=47, df_num=2
# ssr based chi2 test:   chi2=3.0108  , p=0.2219  , df=2
# likelihood ratio test: chi2=2.9269  , p=0.2314  , df=2
# parameter F test:         F=1.3607  , p=0.2664  , df_denom=47, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8923  , p=0.4527  , df_denom=44, df_num=3
# ssr based chi2 test:   chi2=3.1027  , p=0.3761  , df=3
# likelihood ratio test: chi2=3.0120  , p=0.3898  , df=3
# parameter F test:         F=0.8923  , p=0.4527  , df_denom=44, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9938  , p=0.1135  , df_denom=41, df_num=4
# ssr based chi2 test:   chi2=9.7259  , p=0.0453  , df=4
# likelihood ratio test: chi2=8.8871  , p=0.0640  , df=4
# parameter F test:         F=1.9938  , p=0.1135  , df_denom=41, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4912  , p=0.2156  , df_denom=38, df_num=5
# ssr based chi2 test:   chi2=9.6141  , p=0.0869  , df=5
# likelihood ratio test: chi2=8.7786  , p=0.1182  , df=5
# parameter F test:         F=1.4912  , p=0.2156  , df_denom=38, df_num=5
#
#
#  ==========
# ==========
# n_lag 	 p-value
# 1 	 0.3255
# 2 	 0.2664
# 3 	 0.4527
# 4 	 0.1135
# 5 	 0.2156
